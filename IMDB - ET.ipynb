# %%
# import dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# importing title ratings from imdb.tsv file
rating_df = pd.read_csv("resources/title.ratings.tsv", sep='\t')
rating_df.sort_values('averageRating', ascending=False)
# Out:
#             tconst  averageRating  numVotes
# 974523   tt4758048           10.0         6
# 971431   tt4705894           10.0         5
# 970900   tt4698930           10.0         6
# 970891   tt4698836           10.0         6
# 970887   tt4698822           10.0         7
# ...            ...            ...       ...
# 1054681  tt6105420            1.0       101
# 1086137  tt6698638            1.0        29
# 664716   tt1485655            1.0        13
# 529896   tt1164701            1.0         7
# 783443   tt2100624            1.0       458
#
# [1211070 rows x 3 columns]

# %%
# importing basic information from imbd.tsv file

basics_df = pd.read_csv("resources/title.basic.tsv", sep='\t', low_memory=False)
basics_df.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
# checking the different variables in titleType so we can filter and just recieve the movie data

basics_df['titleType'].unique()
# Out:
# array(['short', 'movie', 'tvEpisode', 'tvSeries', 'tvShort', 'tvMovie',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame', 'tvPilot'],
#       dtype=object)

# %%
# filtering the data

filtered_df = basics_df.loc[basics_df['titleType'] == 'movie']
filtered_df.head(20)
# Out:
#         tconst titleType                                     primaryTitle  \
# 498  tt0000502     movie                                         Bohemios
# 570  tt0000574     movie                      The Story of the Kelly Gang
# 587  tt0000591     movie                                 The Prodigal Son
# 610  tt0000615     movie                               Robbery Under Arms
# 625  tt0000630     movie                                           Hamlet
# 668  tt0000675     movie                                      Don Quijote
# 672  tt0000679     movie                   The Fairylogue and Radio-Plays
# 729  tt0000739     movie                        El pastorcito de Torrente
# 783  tt0000793     movie                                    Andreas Hofer
# 804  tt0000814     movie                           La bocana de Mar Chica
# 828  tt0000838     movie                               A Cultura do Cacau
# 832  tt0000842     movie                            De Garraf a Barcelona
# 836  tt0000846     movie                             Un día en Xochimilco
# 840  tt0000850     movie                                 Los dos hermanos
# 849  tt0000859     movie  Fabricación del corcho en Sant Feliu de Guixols
# 852  tt0000862     movie                                       Faldgruben
# 857  tt0000867     movie                                  Fiesta de toros
# 858  tt0000868     movie                 Fiestas de Santa Lucía - Belenes
# 859  tt0000869     movie                            Fiestas en La Garriga
# 869  tt0000879     movie            Gira política de Madero y Pino Suárez
#
#                                        originalTitle isAdult startYear  \
# 498                                         Bohemios       0      1905
# 570                      The Story of the Kelly Gang       0      1906
# 587                                L'enfant prodigue       0      1907
# 610                               Robbery Under Arms       0      1907
# 625                                           Amleto       0      1908
# 668                                      Don Quijote       0      1908
# 672                   The Fairylogue and Radio-Plays       0      1908
# 729                        El pastorcito de Torrente       0      1908
# 783                                    Andreas Hofer       0      1909
# 804                           La bocana de Mar Chica       0      1909
# 828                               A Cultura do Cacau       0      1909
# 832                            De Garraf a Barcelona       0      1909
# 836                             Un día en Xochimilco       0      1909
# 840                                 Los dos hermanos       0      1909
# 849  Fabricación del corcho en Sant Feliu de Guixols       0      1909
# 852                                       Faldgruben       0      1909
# 857                                  Fiesta de toros       0      1909
# 858                 Fiestas de Santa Lucía - Belenes       0      1909
# 859                            Fiestas en La Garriga       0      1909
# 869            Gira política de Madero y Pino Suárez       0      1909
#
#     endYear runtimeMinutes                      genres
# 498      \N            100                          \N
# 570      \N             70  Action,Adventure,Biography
# 587      \N             90                       Drama
# 610      \N             \N                       Drama
# 625      \N             \N                       Drama
# 668      \N             \N                       Drama
# 672      \N            120           Adventure,Fantasy
# 729      \N             \N                       Drama
# 783      \N             \N                       Drama
# 804      \N             \N                          \N
# 828      \N             \N                          \N
# 832      \N             \N                          \N
# 836      \N             \N                          \N
# 840      \N             \N                          \N
# 849      \N             \N                          \N
# 852      \N             \N                          \N
# 857      \N             \N                          \N
# 858      \N             \N                          \N
# 859      \N             \N                          \N
# 869      \N             \N                          \N

# %%
# merging the two dataframes on the tconst column

merged_data = pd.merge(rating_df, filtered_df, on="tconst", how="left")
merged_data.head(20)

# null values are recieved for many values as we are unable to filter by movie on the ratings table
# Out:
#        tconst  averageRating  numVotes titleType primaryTitle originalTitle  \
# 0   tt0000001            5.7      1853       NaN          NaN           NaN
# 1   tt0000002            6.0       241       NaN          NaN           NaN
# 2   tt0000003            6.5      1621       NaN          NaN           NaN
# 3   tt0000004            6.0       156       NaN          NaN           NaN
# 4   tt0000005            6.2      2449       NaN          NaN           NaN
# 5   tt0000006            5.2       162       NaN          NaN           NaN
# 6   tt0000007            5.4       761       NaN          NaN           NaN
# 7   tt0000008            5.5      1998       NaN          NaN           NaN
# 8   tt0000009            5.9       192       NaN          NaN           NaN
# 9   tt0000010            6.9      6697       NaN          NaN           NaN
# 10  tt0000011            5.2       342       NaN          NaN           NaN
# 11  tt0000012            7.5     11490       NaN          NaN           NaN
# 12  tt0000013            5.8      1772       NaN          NaN           NaN
# 13  tt0000014            7.1      5161       NaN          NaN           NaN
# 14  tt0000015            6.2       974       NaN          NaN           NaN
# 15  tt0000016            5.9      1371       NaN          NaN           NaN
# 16  tt0000017            4.6       303       NaN          NaN           NaN
# 17  tt0000018            5.3       556       NaN          NaN           NaN
# 18  tt0000019            5.2        30       NaN          NaN           NaN
# 19  tt0000020            4.9       327       NaN          NaN           NaN
#
#    isAdult startYear endYear runtimeMinutes genres
# 0      NaN       NaN     NaN            NaN    NaN
# 1      NaN       NaN     NaN            NaN    NaN
# 2      NaN       NaN     NaN            NaN    NaN
# 3      NaN       NaN     NaN            NaN    NaN
# 4      NaN       NaN     NaN            NaN    NaN
# 5      NaN       NaN     NaN            NaN    NaN
# 6      NaN       NaN     NaN            NaN    NaN
# 7      NaN       NaN     NaN            NaN    NaN
# 8      NaN       NaN     NaN            NaN    NaN
# 9      NaN       NaN     NaN            NaN    NaN
# 10     NaN       NaN     NaN            NaN    NaN
# 11     NaN       NaN     NaN            NaN    NaN
# 12     NaN       NaN     NaN            NaN    NaN
# 13     NaN       NaN     NaN            NaN    NaN
# 14     NaN       NaN     NaN            NaN    NaN
# 15     NaN       NaN     NaN            NaN    NaN
# 16     NaN       NaN     NaN            NaN    NaN
# 17     NaN       NaN     NaN            NaN    NaN
# 18     NaN       NaN     NaN            NaN    NaN
# 19     NaN       NaN     NaN            NaN    NaN

# %%
# dropping the null values, so we only have the data for movies

clean_data = merged_data.dropna()

# %%
# sorting the data by number of votes

rating_clean_data = clean_data.sort_values('numVotes', ascending=False)
rating_clean_data.head(20)
# Out:
#            tconst  averageRating  numVotes titleType  \
# 82428   tt0111161            9.3   2536461     movie
# 250189  tt0468569            9.0   2486973     movie
# 623125  tt1375666            8.8   2228680     movie
# 98961   tt0137523            8.8   1996157     movie
# 81335   tt0109830            8.8   1957578     movie
# 82212   tt0110912            8.9   1952890     movie
# 96780   tt0133093            8.7   1830941     movie
# 90218   tt0120737            8.8   1771272     movie
# 114196  tt0167260            8.9   1749747     movie
# 46156   tt0068646            9.2   1745695     movie
# 395325  tt0816692            8.6   1682038     movie
# 610630  tt1345836            8.4   1613447     movie
# 114197  tt0167261            8.7   1580921     movie
# 84980   tt0114369            8.6   1556174     movie
# 750056  tt1853728            8.4   1466494     movie
# 116665  tt0172495            8.5   1431491     movie
# 209798  tt0372784            8.2   1389287     movie
# 204654  tt0361748            8.3   1368426     movie
# 75616   tt0102926            8.6   1363309     movie
# 406269  tt0848228            8.0   1335933     movie
#
#                                              primaryTitle  \
# 82428                            The Shawshank Redemption
# 250189                                    The Dark Knight
# 623125                                          Inception
# 98961                                          Fight Club
# 81335                                        Forrest Gump
# 82212                                        Pulp Fiction
# 96780                                          The Matrix
# 90218   The Lord of the Rings: The Fellowship of the Ring
# 114196      The Lord of the Rings: The Return of the King
# 46156                                       The Godfather
# 395325                                       Interstellar
# 610630                              The Dark Knight Rises
# 114197              The Lord of the Rings: The Two Towers
# 84980                                               Se7en
# 750056                                   Django Unchained
# 116665                                          Gladiator
# 209798                                      Batman Begins
# 204654                               Inglourious Basterds
# 75616                            The Silence of the Lambs
# 406269                                       The Avengers
#
#                                             originalTitle isAdult startYear  \
# 82428                            The Shawshank Redemption       0      1994
# 250189                                    The Dark Knight       0      2008
# 623125                                          Inception       0      2010
# 98961                                          Fight Club       0      1999
# 81335                                        Forrest Gump       0      1994
# 82212                                        Pulp Fiction       0      1994
# 96780                                          The Matrix       0      1999
# 90218   The Lord of the Rings: The Fellowship of the Ring       0      2001
# 114196      The Lord of the Rings: The Return of the King       0      2003
# 46156                                       The Godfather       0      1972
# 395325                                       Interstellar       0      2014
# 610630                              The Dark Knight Rises       0      2012
# 114197              The Lord of the Rings: The Two Towers       0      2002
# 84980                                               Se7en       0      1995
# 750056                                   Django Unchained       0      2012
# 116665                                          Gladiator       0      2000
# 209798                                      Batman Begins       0      2005
# 204654                               Inglourious Basterds       0      2009
# 75616                            The Silence of the Lambs       0      1991
# 406269                                       The Avengers       0      2012
#
#        endYear runtimeMinutes                   genres
# 82428       \N            142                    Drama
# 250189      \N            152       Action,Crime,Drama
# 623125      \N            148  Action,Adventure,Sci-Fi
# 98961       \N            139                    Drama
# 81335       \N            142            Drama,Romance
# 82212       \N            154              Crime,Drama
# 96780       \N            136            Action,Sci-Fi
# 90218       \N            178   Action,Adventure,Drama
# 114196      \N            201   Action,Adventure,Drama
# 46156       \N            175              Crime,Drama
# 395325      \N            169   Adventure,Drama,Sci-Fi
# 610630      \N            164       Action,Crime,Drama
# 114197      \N            179   Action,Adventure,Drama
# 84980       \N            127      Crime,Drama,Mystery
# 750056      \N            165            Drama,Western
# 116665      \N            155   Action,Adventure,Drama
# 209798      \N            140       Action,Crime,Drama
# 204654      \N            153      Adventure,Drama,War
# 75616       \N            118       Crime,Drama,Horror
# 406269      \N            143  Action,Adventure,Sci-Fi

# %%
# resetting index

sorted_data = rating_clean_data.reset_index()
sorted_data.head(20)
# Out:
#      index     tconst  averageRating  numVotes titleType  \
# 0    82428  tt0111161            9.3   2536461     movie
# 1   250189  tt0468569            9.0   2486973     movie
# 2   623125  tt1375666            8.8   2228680     movie
# 3    98961  tt0137523            8.8   1996157     movie
# 4    81335  tt0109830            8.8   1957578     movie
# 5    82212  tt0110912            8.9   1952890     movie
# 6    96780  tt0133093            8.7   1830941     movie
# 7    90218  tt0120737            8.8   1771272     movie
# 8   114196  tt0167260            8.9   1749747     movie
# 9    46156  tt0068646            9.2   1745695     movie
# 10  395325  tt0816692            8.6   1682038     movie
# 11  610630  tt1345836            8.4   1613447     movie
# 12  114197  tt0167261            8.7   1580921     movie
# 13   84980  tt0114369            8.6   1556174     movie
# 14  750056  tt1853728            8.4   1466494     movie
# 15  116665  tt0172495            8.5   1431491     movie
# 16  209798  tt0372784            8.2   1389287     movie
# 17  204654  tt0361748            8.3   1368426     movie
# 18   75616  tt0102926            8.6   1363309     movie
# 19  406269  tt0848228            8.0   1335933     movie
#
#                                          primaryTitle  \
# 0                            The Shawshank Redemption
# 1                                     The Dark Knight
# 2                                           Inception
# 3                                          Fight Club
# 4                                        Forrest Gump
# 5                                        Pulp Fiction
# 6                                          The Matrix
# 7   The Lord of the Rings: The Fellowship of the Ring
# 8       The Lord of the Rings: The Return of the King
# 9                                       The Godfather
# 10                                       Interstellar
# 11                              The Dark Knight Rises
# 12              The Lord of the Rings: The Two Towers
# 13                                              Se7en
# 14                                   Django Unchained
# 15                                          Gladiator
# 16                                      Batman Begins
# 17                               Inglourious Basterds
# 18                           The Silence of the Lambs
# 19                                       The Avengers
#
#                                         originalTitle isAdult startYear  \
# 0                            The Shawshank Redemption       0      1994
# 1                                     The Dark Knight       0      2008
# 2                                           Inception       0      2010
# 3                                          Fight Club       0      1999
# 4                                        Forrest Gump       0      1994
# 5                                        Pulp Fiction       0      1994
# 6                                          The Matrix       0      1999
# 7   The Lord of the Rings: The Fellowship of the Ring       0      2001
# 8       The Lord of the Rings: The Return of the King       0      2003
# 9                                       The Godfather       0      1972
# 10                                       Interstellar       0      2014
# 11                              The Dark Knight Rises       0      2012
# 12              The Lord of the Rings: The Two Towers       0      2002
# 13                                              Se7en       0      1995
# 14                                   Django Unchained       0      2012
# 15                                          Gladiator       0      2000
# 16                                      Batman Begins       0      2005
# 17                               Inglourious Basterds       0      2009
# 18                           The Silence of the Lambs       0      1991
# 19                                       The Avengers       0      2012
#
#    endYear runtimeMinutes                   genres
# 0       \N            142                    Drama
# 1       \N            152       Action,Crime,Drama
# 2       \N            148  Action,Adventure,Sci-Fi
# 3       \N            139                    Drama
# 4       \N            142            Drama,Romance
# 5       \N            154              Crime,Drama
# 6       \N            136            Action,Sci-Fi
# 7       \N            178   Action,Adventure,Drama
# 8       \N            201   Action,Adventure,Drama
# 9       \N            175              Crime,Drama
# 10      \N            169   Adventure,Drama,Sci-Fi
# 11      \N            164       Action,Crime,Drama
# 12      \N            179   Action,Adventure,Drama
# 13      \N            127      Crime,Drama,Mystery
# 14      \N            165            Drama,Western
# 15      \N            155   Action,Adventure,Drama
# 16      \N            140       Action,Crime,Drama
# 17      \N            153      Adventure,Drama,War
# 18      \N            118       Crime,Drama,Horror
# 19      \N            143  Action,Adventure,Sci-Fi

# %%
# taking the columns we need and renaming them for ease of use

sorted_data1 = sorted_data[['averageRating', 'numVotes', 'primaryTitle']]
rename_df = sorted_data1.rename(columns={'primaryTitle': 'Title', 'averageRating': 'Movie Rating', 'numVotes': 'User Votes'})
rename_df.head(20)
# Out:
#     Movie Rating  User Votes  \
# 0            9.3     2536461
# 1            9.0     2486973
# 2            8.8     2228680
# 3            8.8     1996157
# 4            8.8     1957578
# 5            8.9     1952890
# 6            8.7     1830941
# 7            8.8     1771272
# 8            8.9     1749747
# 9            9.2     1745695
# 10           8.6     1682038
# 11           8.4     1613447
# 12           8.7     1580921
# 13           8.6     1556174
# 14           8.4     1466494
# 15           8.5     1431491
# 16           8.2     1389287
# 17           8.3     1368426
# 18           8.6     1363309
# 19           8.0     1335933
#
#                                                 Title
# 0                            The Shawshank Redemption
# 1                                     The Dark Knight
# 2                                           Inception
# 3                                          Fight Club
# 4                                        Forrest Gump
# 5                                        Pulp Fiction
# 6                                          The Matrix
# 7   The Lord of the Rings: The Fellowship of the Ring
# 8       The Lord of the Rings: The Return of the King
# 9                                       The Godfather
# 10                                       Interstellar
# 11                              The Dark Knight Rises
# 12              The Lord of the Rings: The Two Towers
# 13                                              Se7en
# 14                                   Django Unchained
# 15                                          Gladiator
# 16                                      Batman Begins
# 17                               Inglourious Basterds
# 18                           The Silence of the Lambs
# 19                                       The Avengers

# %%
rename_df.to_csv('imdb_data.csv', index=False)
